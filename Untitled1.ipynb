# %%
idict={'卫生和社会工作': 309.58702600000004,
 '其他': 44.436987,
 '批发和零售业': 250.816889,
 '信息传输、软件和信息技术服务业': 296.122009,
 '电力、热力、燃气及水生产和供应业': 316.705625,
 '采矿业': 241.69402300000002,
 '信息技术': 115.23441600000001,
 '通信服务': 57.47487300000001,
 '制造业': 5174.342536999999,
 '文化、体育和娱乐业': 33.216027,
 '建筑业': 17.372577,
 '科学研究和技术服务业': 11.407976999999999,
 '租赁和商务服务业': 129.143552,
 '非日常生活消费品': 43.497576,
 '金融业': 2614.6995879999995,
 '房地产业': 297.504578,
 '农、林、牧、渔业': 246.728431,
 '水利、环境和公共设施管理业': 6.367355999999999,
 '交通运输、仓储和邮政业': 237.34964800000003}

# %%
import pandas as pd
indy= []
money = []
for tp in idict.items():
    indy.append(tp[0])
    money.append(tp[1])
perc = [m/sum(money) for m in money]
ind2pec = pd.DataFrame({'industry':indy,'percent':perc})

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.figure(figsize=(15, 10))
sns.set(font='simhei')
sns.axes_style("darkgrid")
sns.barplot(x="industry",y="percent",data=ind2pec)
sns.despine(offset=10, trim=True)
# Out:
# /Users/alfonso/workplace/summarization/venv/lib/python3.6/site-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['simhei'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
